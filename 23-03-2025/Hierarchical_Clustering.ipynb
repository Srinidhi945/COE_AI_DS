# %% [markdown]
# **Agglomerative clustering**

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# %%
x=np.array([[1,2],[1,4],[1,0],[4,2],[4,4],[4,0]])

# %%
clustering=AgglomerativeClustering(n_clusters=2).fit(x)

# %%
print(clustering.labels_)
# Out:
# [1 1 1 0 0 0]

# %% [markdown]
# **Divisive clustering**

# %%
from scipy.cluster.hierarchy import dendrogram,linkage
import matplotlib.pyplot as plt

# %%
y=np.array([[1,2],[1,4],[1,0],[4,2],[4,4],[4,0]])

# %%
z=linkage(y,'ward')

# %%
dendrogram(z)
# Out:
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [35.0, 35.0, 50.0, 50.0],
#   [12.5, 12.5, 42.5, 42.5]],
#  'dcoord': [[0.0, 2.0, 2.0, 0.0],
#   [0.0, 3.4641016151377544, 3.4641016151377544, 2.0],
#   [0.0, 2.0, 2.0, 0.0],
#   [0.0, 3.4641016151377544, 3.4641016151377544, 2.0],
#   [3.4641016151377544,
#    5.196152422706632,
#    5.196152422706632,
#    3.4641016151377544]],
#  'ivl': ['2', '0', '1', '4', '3', '5'],
#  'leaves': [2, 0, 1, 4, 3, 5],
#  'color_list': ['C1', 'C1', 'C2', 'C2', 'C0'],
#  'leaves_color_list': ['C1', 'C1', 'C1', 'C2', 'C2', 'C2']}

# %%
dendrogram(z)
plt.title('Hierarchical clustering dendorgam')
plt.xlabel('data point')
plt.ylabel('distance')
plt.show()
