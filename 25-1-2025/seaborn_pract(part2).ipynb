# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
t=pd.read_csv(r'C:\Users\CVR\Downloads\train.csv')

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#1)how does passengar class(Pclass) relate to survival rate?
#use a bar plot to compare the survival rates across different classes
#dataset:train

# %%
(t.isnull()).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
t.dropna(inplace=True)

# %%
(t.isnull()).sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
t.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sns.barplot(data=t,x="Pclass",y="Survived",palette='coolwarm')
plt.title("Survival rate by passenger class")
plt.xlabel("passenger class")
plt.ylabel("survuval rate")
plt.show()

# %%
#2)is there any relationship between passenger age and fare?
#create a scatter plot

# %%
t.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sns.scatterplot(data=t,x=t['Age'],y=t['Fare'],palette='deep')
plt.show("scatter plot for passenger age and fare")
plt.show()
# Out:
# C:\Users\CVR\AppData\Local\Temp\ipykernel_1684\2650356518.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=t,x=t['Age'],y=t['Fare'],palette='deep')

# %%
#3)what are the pairwise relationships between age ,fare and passenger class>
#pair plot

# %%
sns.pairplot(data=t[['Age','Fare','Pclass']],palette='coolwarm')
plt.show()
# Out:
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
#what is the correlation between numerical features in dataset?
#compute a correlation matrix and visualize a heat map

# %%
t.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
numeric_cols=t.select_dtypes(include=['float64','int64'])
cor_mat=numeric_cols.corr()
sns.heatmap(cor_mat,annot=True,cmap="Blues",fmt='.2f')
plt.show()
