# %%
import pandas as pd
import numpy as np

# %%
cs=pd.read_csv(r"C:\Users\CVR\Downloads\COE\coffeshop.csv")

# %%
cs
# Out:
#     Order_ID        Date Customer_ID        Item    Size  Quantity  \
# 0          1  2025-01-01        C001    Espresso   Small         1
# 1          2  2025-01-01        C002       Latte  Medium         2
# 2          3  2025-01-01        C003  Cappuccino   Large         1
# 3          4  2025-01-01        C004   Americano  Medium         1
# 4          5  2025-01-01        C001       Mocha   Small         1
# 5          6  2025-01-02        C005    Espresso   Large         2
# 6          7  2025-01-02        C002       Latte   Small         1
# 7          8  2025-01-02        C006   Americano  Medium         1
# 8          9  2025-01-02        C003       Mocha   Large         1
# 9         10  2025-01-03        C007  Cappuccino  Medium         2
# 10        11  2025-01-03        C008    Espresso   Small         1
# 11        12  2025-01-03        C009       Latte   Large         1
# 12        13  2025-01-04        C010   Americano   Large         2
# ...

# %%
cs.drop(columns={'Hour','Payment_Method'})
# Out:
#     Order_ID        Date Customer_ID        Item    Size  Quantity  \
# 0          1  2025-01-01        C001    Espresso   Small         1
# 1          2  2025-01-01        C002       Latte  Medium         2
# 2          3  2025-01-01        C003  Cappuccino   Large         1
# 3          4  2025-01-01        C004   Americano  Medium         1
# 4          5  2025-01-01        C001       Mocha   Small         1
# 5          6  2025-01-02        C005    Espresso   Large         2
# 6          7  2025-01-02        C002       Latte   Small         1
# 7          8  2025-01-02        C006   Americano  Medium         1
# 8          9  2025-01-02        C003       Mocha   Large         1
# 9         10  2025-01-03        C007  Cappuccino  Medium         2
# 10        11  2025-01-03        C008    Espresso   Small         1
# 11        12  2025-01-03        C009       Latte   Large         1
# 12        13  2025-01-04        C010   Americano   Large         2
# ...

# %%
t=pd.read_csv(r"C:\Users\CVR\Downloads\COE\titanic.csv")

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
survival=t['Survived']

# %%
survival
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
t.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
num_cols=t.select_dtypes(include=['int64','float64'])

# %%
num_cols
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
y=num_cols['Survived']
x=num_cols.drop(columns='Survived',axis=1)
x.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0            1       3  22.0      1      0   7.2500
# 1            2       1  38.0      1      0  71.2833
# 2            3       3  26.0      0      0   7.9250
# 3            4       1  35.0      1      0  53.1000
# 4            5       3  35.0      0      0   8.0500

# %%
x.corr().round(2)
# Out:
#              PassengerId  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00   -0.04  0.04  -0.06  -0.00  0.01
# Pclass             -0.04    1.00 -0.37   0.08   0.02 -0.55
# Age                 0.04   -0.37  1.00  -0.31  -0.19  0.10
# SibSp              -0.06    0.08 -0.31   1.00   0.41  0.16
# Parch              -0.00    0.02 -0.19   0.41   1.00  0.22
# Fare                0.01   -0.55  0.10   0.16   0.22  1.00

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(x.corr().round(2),annot=True,cmap="Blues")
# Out:
# <Axes: >

# %%
#collecting raw data
#dropping unnecessary columns 
#finding dtypes of the columns present
#understanding the correlation between the columns
#label encoding-if ordinal data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data={'Grade':['A','B','C','D','F']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Grade
# 0     A
# 1     B
# 2     C
# 3     D
# 4     F

# %%
encoder=LabelEncoder()

# %%
df['Grade_encoded']=encoder.fit_transform(df['Grade'])

# %%
df
# Out:
#   Grade  Grade_encoded
# 0     A              0
# 1     B              1
# 2     C              2
# 3     D              3
# 4     F              4

# %%
df['TestScore']=[50,60,70,80,90]

# %%
corr=df['Grade_encoded'].corr(df['TestScore'])
print("Correlation",corr)
# Out:
# Correlation 1.0

# %%
d={'color':['Red','Blue','Green','Blue','Red'],'Test Score':[50,60,70,80,90]}

# %%
dfr=pd.DataFrame(d)

# %%
dfr
# Out:
#    color  Test Score
# 0    Red          50
# 1   Blue          60
# 2  Green          70
# 3   Blue          80
# 4    Red          90

# %%
dfr_encoded=pd.get_dummies(dfr,columns=['color'])

# %%
dfr_encoded
# Out:
#    Test Score  color_Blue  color_Green  color_Red
# 0          50       False        False       True
# 1          60        True        False      False
# 2          70       False         True      False
# 3          80        True        False      False
# 4          90       False        False       True

# %%
corrl=dfr_encoded['color_Red'].corr(dfr_encoded['Test Score'])

# %%
corrl
# Out:
# -1.2819751242557094e-17
