# %%
#distribution
import numpy as np
import matplotlib.pyplot as plt

# %%
#bernoulli distrobution

from scipy.stats import bernoulli

p=0.6

data=bernoulli.rvs(p,size=1000)

plt.bar([0,1],[sum(data==0),sum(data == 1)],color=['red','green'],tick_label=["Failure(0)","Success(1)"])
plt.xlabel("outcome")
plt.ylabel("frequency")
plt.title("bernoulli distribution (p=0.6)")
plt.show()

# %%
#binomial distribution
from scipy.stats import binom
n=10
p=0.3
x=np.arange(0,n+1)
pmf=binom.pmf(x,n,p)
plt.bar(x,pmf,color='blue',alpha=0.7)
plt.xlabel("number of successes(clicks)")
plt.ylabel("probability")
plt.title(f"binomial distribution (n={n}.p={p})")
plt.show()

# %%
#poisson distribution
from scipy.stats import poisson
λ=3
x=np.arange(0,10)
pmf=poisson.pmf(x,λ)
plt.bar(x,pmf,color='purple',alpha=0.7)
plt.xlabel("number of calls per min")
plt.ylabel("probability")
plt.title(f"poisson distribution(λ={λ})")
plt.show()

# %%
#normal distribution

from scipy.stats import norm
mu=70
sigma=10
x=np.linspace(mu-4*sigma,mu+4*sigma,100)
pdf=norm.pdf(x,mu,sigma)

plt.plot(x,pdf,color='red',label=f"N({mu},{sigma}^2)")
plt.xlabel("exam scores")
plt.ylabel("probability density")
plt.title(f"Normal distribution (μ={mu},σ={sigma})")
plt.legend()
plt.grid()
plt.show()

# %%
#standard normal distribution (z-distribution)

from scipy.stats import norm
z=np.linspace(-4, 4, 1000)
pdf=norm.pdf(z,0,1)
plt.plot(z,pdf,color='pink',label="Standard Normal Distribution(μ=0,σ=1)")
plt.xlabel("Z-Score")
plt.ylabel("Probability Density")
plt.title("Standard Normal Distribution (Z-Distribution)")
plt.axvline(x=0,color='red',linestyle='--',label="Mean(z=0)")
plt.legend()
plt.grid()
plt.show()

# %%
#skewed distribution
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#Set random seed for reproducibility
np.random.seed(42)
#Generate a skewed income dataset (exponential distribution)
income_data = np.random.exponential (scale=50, size=1000)
#Plot the original skewed distribution
plt.figure(figsize=(8, 4))
sns.histplot(income_data, bins=50, kde =True, color="r")
plt.title("Original Income Distribution (Skewed)")
plt.xlabel("Income ($1000)")
plt.ylabel("Frequency")
plt.show()

# %%
#Perform sampling and calculate means
sample_means = []
n_samples=1000
# Number of samples
sample_size =30 # Sample size

for _ in range(n_samples):

    sample=np.random.choice(income_data, size= sample_size)

    sample_means.append(np.mean(sample))

#Plot the sampling distribution of the sample mean

plt.figure(figsize=(8, 4))

sns.histplot(sample_means, bins =50, kde =True, color="b")

plt.title(f"Sampling Distribution of Sample Mean (n=(sample_size))")

plt.xlabel("Sample Mean")

plt.ylabel("Frequency")

plt.show()

# %%
#testing
#Z-test ->> if we know population varience and large sample(n>30),eg:comparing heights of students
#t-test->> small sample,unknow population varience ,eg:comparing avg salaries of 2 groups
#chi-square test->> categorical data,eg:checking if gender affects product preference
#anova->>>compare the means of 3 or 4 groups

# %%
#https://drive.google.com/drive/folders/1cYqJxUQ45WKtT3zVQ7Ujv7Rbe0UqYkZl?usp=sharing

# %%
#https://drive.google.com/drive/folders/1cYqJxUQ45WKtT3zVQ7Ujv7Rbe0UqYkZl?usp=sharing
